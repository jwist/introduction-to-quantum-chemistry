# %% [markdown]
# # QIII
#
# **Julien Wist**<br>
# *Universidad del Valle*<br>
# *2016*

# %% [markdown]
# # polyelectronic atoms

# %% [markdown]
# ## the helium atom $(Z=2)$
#
# we can continue our exploration and try do find the *Hamiltonian* for a more complex system: the atom of Helium
#
# <center><img src="../img/referentialHeAtom.svg" width="300"></center>
#
# $$
# \hat{H}=K_{nuc}+K_{elec1}+K_{elec2}+V_{Ne_1}+V_{Ne_2}+V_{e_1e_2}
# $$
#
# $$
# \hat{H}=-\frac{1}{2M}\nabla^2_R-\frac{1}{2}\nabla^2_{r_1}-\frac{1}{2}\nabla^2_{r_2}
# -\frac{2}{|r_1-R|}-\frac{2}{|r_2-R|}+\frac{1}{|r_1-r_2|}
# $$

# %% [markdown]
# ### the proper coordinate system
#
# We first write down the wave function with its degree of freedom
#
# $$
# \Psi(X_N, Y_N ,Z_N ,X_1 ,Y_1 ,Z_1 ,X_2 ,Y_2 ,Z_2)
# $$
#
# We consider the center of mass as origin for our system. In that case our function recast to:
#
# $$
# \varPsi(x_{1}, y_{1},z_{1},x_{2},y_{2},z_{2})
# $$
#
# In atomic units and in the coordinates of the center of mass the *Hamiltonian* is:
#
# $$
# \hat{\mathcal{H}}=-\frac{1}{2}\nabla_1^2-\frac{1}{2}\nabla_2^2-\frac{2}{\sqrt{x_1^2+y_1^2+z_1^2}}-\frac{2}{\sqrt{x_2^2+y_2^2+z_2^2}}
# +\frac{1}{\sqrt{(x_1-x_2)^2+(y_1-y_2)^2+(z_1-z_2)^2}}
# $$
#
# Remember... the cartesian system is not really good for spherical symmetries
#
# $$
# \varPsi(x_{1},y_{1}, z_{1}, x_{2}, y_{2}, z_{2})\equiv\varPsi(r_1, \theta_1, \phi_1, r_2, \theta_2, \phi_2)
# $$

# %% [markdown]
# ### the Schrödinger equation
#
# $$
# \varPsi(\vec{r}_1,\vec{r}_2)
# $$
#
# $$
# \hat{\mathcal{H}}=-\frac{1}{2}\nabla_1^2-\frac{1}{2}\nabla_2^2-\frac{2}{\vec{r}_1}-\frac{2}{\vec{r}_2}+\frac{1}{r_{12}}
# $$
#
# $$
# \hat{\mathcal{H}}\varPsi(\vec{r}_1,\vec{r}_2)=E_e\varPsi(\vec{r}_1,\vec{r}_2)
# $$
#
# $r^{-1}_{12}$ makes the separation of variable impossible!

# %% [markdown]
# ### first approximation
#
# as a first approximation we can simply drop the repulsion term. In this case we can write our *Hamiltonian* as the sum:
#
# $$
# \hat{H}=\hat{h}(\vec{r}_1)+\hat{h}(\vec{r}_2)
# $$
# $$
# \hat{h}(\vec{r}_i)=-\frac{1}{2}\nabla_i^2-\frac{2}{\vec{r}_i}
# $$
#
# And the equation to be solved is:
#
# $$
# \hat{H}\psi(\vec{r}_1,\vec{r}_2)=W\psi(\vec{r}_1,\vec{r}_2)
# $$
#
# We only have to assume $\psi(\vec{r}_1,\vec{r}_2)=\phi_1(\vec{r}_1)\phi_2(\vec{r}_2)$ in order to proceed with the separation of variables.

# %% [markdown]
# ### the separation of variables
#
# $$
# \hat{H}\psi(\vec{r}_1,\vec{r}_2)=W\phi_1(\vec{r}_1)\phi_2(\vec{r}_2)
# $$
# $$
# \Bigl[\hat{h}(\vec{r}_1)+\hat{h}(\vec{r}_2)\Bigr]\phi_1(\vec{r}_1)\phi_2(\vec{r}_2)=W\phi_1(\vec{r}_1)\phi_2(\vec{r}_2)
# $$
#
# $$
# \hat{h}(\vec{r}_1)\phi_1(\vec{r}_1)=\epsilon_1\phi_1(\vec{r}_1)
# $$
# $$
# \hat{h}(\vec{r}_2)\phi_2(\vec{r}_2)=\epsilon_2\phi_2(\vec{r}_2)
# $$
#
# $$
# W=\epsilon_1+\epsilon_2
# $$

# %% [markdown]
# Ignoring the repulsion term we can factor the wave function, that is we consider the total wavefunction as the product of two *monoelectronic* functions, or 2 *orbitals*. Since we already know theses functions we can readily solve the problem:
#
# $$
# \phi_i(\vec{r}_i)\in \{ 1s(\vec{r}_i), 2s(\vec{r}_i), 2p_x(\vec{r}_i), 2p_y(\vec{r}_i), 2p_z(\vec{r}_i), 3s(\vec{r}_i), \ldots \}
# $$
#
# So we have to find two functions that give the lowest possible energy:
#
# $$
# \psi(\vec{r}_1,\vec{r}_2)=\phi_1(\vec{r}_1)\phi_2(\vec{r}_2)=1s_1(\vec{r}_1)1s_2(\vec{r}_2)
# $$
#
# and the energy (a.u.) is:
#
# $$
# W = \epsilon_1 + \epsilon_2 =\frac{-Z^2}{2n_1^2} + \frac{-Z^2}{2n_2^2}= -4 \quad hartrees
# $$
#
# If both electrons are in $1s(\vec{r}_i)$

# %% [markdown]
# ## variational teorem
#
# Because we know the correct *Hamiltonian* but we don't know how to find the eignenfunction, we can use the following equation to find an approximation to the energy:
#
# $$
# \langle E \rangle= \frac {\iint\limits\psi^*(\vec{r}_1,\vec{r}_2)\hat{\mathcal{H}}\,\psi(\vec{r}_1,\vec{r}_2)d\tau_1\,d\tau_2}{ \iint\limits\psi^*(\vec{r}_1,\vec{r}_2)\psi(\vec{r}_1,\vec{r}_2)d\tau_1\,d\tau_2}
# $$
#
# **NOTE:** in order to obtain an approximation for the energy we need to provide *functions*. Therefore the importance of orbitals
#
# Looking at the denominator:
#
# $$
# \iint\limits1s_1^2(\vec{r}_1)1s_2^2(\vec{r}_2)d\tau_1\,d\tau_2=\int\limits|1s_1(\vec{r}_1)|^2d\tau_1\int\limits|1s_2(\vec{r}_2)|^2d\tau_2 \equiv 1
# $$

# %% [markdown]
# $$
# \langle E \rangle =\iint\limits 1s_1(\vec{r}_1)1s_2(\vec{r}_2) \hat{\mathcal{H}}\,1s_1(\vec{r}_1)1s_2(\vec{r}_2)d\tau_1\,d\tau_2
# $$
# $$
# \langle E \rangle =\iint\limits 1s_1(\vec{r}_1)1s_2(\vec{r}_2)\Bigl[\hat{h}(\vec{r}_1)+\hat{h}(\vec{r}_2)+r_{12}^{-1}\Bigr]1s_1(\vec{r}_1)1s_2(\vec{r}_2)d\tau_1\,d\tau_2
# $$
#
# $$
# \langle E \rangle=\iint\limits 1s_1(\vec{r}_1)1s_2(\vec{r}_2)\hat{h}(\vec{r}_1)1s_1(\vec{r}_1)1s_2(\vec{r}_2)d\tau_1\,d\tau_2 +  \\
# \iint\limits 1s_1(\vec{r}_1)1s_2(\vec{r}_2)\hat{h}(\vec{r}_2)1s_1(\vec{r}_1)1s_2(\vec{r}_2)d\tau_1\,d\tau_2 + \\
# \iint\limits 1s_1(\vec{r}_1)1s_2(\vec{r}_2)\,r_{12}^{-1}1s_1(\vec{r}_1)1s_2(\vec{r}_2)d\tau_1\,d\tau_2
# $$
#
# We already solved the first two lines and remember that they are equal to $\epsilon_1$ and $\epsilon_2$. We only have to solve the third line.
#
# $$\langle E \rangle=\epsilon_1\,+ \epsilon_2\, + \frac{5}{8}\,Z=-2-2+5/4=-2.75 \quad hartrees$$
#
# Let's look at the sign of the contributions. The monoelectronic parts are negative and thus contribute to the stabilization of the atom, while the repulsion term (Coulomb integral) is positive.
#
# **NOTE:** the experimental value is $-2.905$ so you can evaluate the relative error!

# %% [markdown]
# test variational method on 1D box using python

# %% [markdown]
# ## ionization potential
#
# What would be the ionization potencial?
#
# $$He \to He^{+} + e^{-}$$
#
# **Note:** the energy of a free particle is assumed to be cero. The experimental potential is $0.903$ hartrees

# %% [markdown]
# ## electronic configuration
#
#  - to evaluate $\langle E \rangle$ we have to provide the monoelectronic functions
#  - unperturbed energy (without repulsion) only depends on $n$
#  - we have to find the configuration of lower energy
#
# What would be the order in absence of repulsion
#
# $$ 1s(\vec{r})<2s(\vec{r})=2p(\vec{r})<3s(\vec{r})=3p(\vec{r})=3d(\vec{r})<4s(\vec{r}) \dots$$
#
# becomes<br>
#
# $$1s(\vec{r})<2s(\vec{r})<2p(\vec{r})<3s(\vec{r})<3p(\vec{r})<3d(\vec{r})<4s(\vec{r}) \dots$$
#
# **So the electronic repulsion (the Coulomb integrals) is removing degeneracy.**

# %% [markdown]
# ## spectroscopic terms
#
# <img src="../img/1.png" width="500">

# %% [markdown]
# ## spectroscopic terms
#
# <img src="../img/2.png" width="500">

# %% [markdown]
# ## bielectronic Coulomb integrals
#
# $$
# J_{1s1s}=\bigl <1s(\vec{r}_i)1s(\vec{r}_j)|\frac{1}{r_{ij}}|1s(\vec{r}_i)1s(\vec{r}_j)\bigr>=\frac{5}{8}Z\\
# J_{1s2s}=\bigl <1s(\vec{r}_i)2s(\vec{r}_j)|\frac{1}{r_{ij}}|1s(\vec{r}_i)2s(\vec{r}_j)\bigr>=\frac{17}{81}Z\\
# J_{2s2s}=\bigl <2s(\vec{r}_i)2s(\vec{r}_j)|\frac{1}{r_{ij}}|2s(\vec{r}_i)2s(\vec{r}_j)\bigr>=\frac{37}{83}Z \\
# J_{2s2p}=\bigl <2s(\vec{r}_i)2p(\vec{r}_j)|\frac{1}{r_{ij}}|2s(\vec{r}_i)2p(\vec{r}_j)\bigr>=\frac{59}{243}Z
# $$

# %% [markdown]
# # Pauli exclusion principle

# %% [markdown]
# ## the symmetry and the anti-symmetry
#
# For polyelectronic atoms we obtain wavefunctions that depends on degrees of freedom for each particle. Remember the trial wavefunction $\psi(\vec{r}_1,\vec{r}_2)=\phi_1(\vec{r}_1)\phi_2(\vec{r}_2)$.
#
# We might reckon however that the results of the calculation cannot change because we swap the two electrons. **that is we must require that the electrons are indistinguishable**

# %% [markdown]
# Let's consider an operator $\hat{P}_{ij}$ whose effect is to swap two particles $i$ and $j$, we can write the eignen equation:
#
# $$\hat{P}_{ij}w(r_1,\ldots, r_i,r_j,\ldots)=c w(r_1,\ldots, r_j,r_i,\ldots )$$
#
# If we apply a second time the operator:
#
# $$\hat{P}_{ij}\hat{P}_{ij}w(r_1,\ldots, r_i,r_j,\ldots)=c \hat{P}_{ij}w(r_1,\ldots, r_j,r_i,\ldots )$$
#
# But by definition $\hat{P}_{ij}\hat{P}_{ij}=\mathbb{1}$ so
#
# $$w(r_1,\ldots, r_i,r_j,\ldots)=c^2 w(r_1,\ldots, r_i,r_j,\ldots )$$
#
# and $c$ should be $\pm 1$ meaning that **swapping** two electron should leave the function untouched or multiplied by -1. Thus the wavefunction must be **symmetric** or **anti-symmetric** with respect to swapping particles

# %% [markdown]
# The requirement that electrons are indistinguishable comes from the fact that we cannot measure repeatidly the postion of $e_1$ and $e_2$ to obtain an expected value. Indeed, suppose that we could measure the position of $e_1$ and $e_2$, when we repeat the measurement, how can we be sure that we get the label correctly? we **cannot** be sure, because we **cannot** distinguish the electrons!

# %% [markdown]
# think about examples of functions $f(x)$ that are symmetric or anti-symmetric with respect to 0
#
#  - symmetric $f(x)=f(-x)$
#  - anti-symmetric $f(x)=-f(-x)$
#
# Try to find symmetric and anti-symmetric function with respect to swapping $x$ and $y$ by combining $f(x)=x^2$ and $g(y)=e^y$

# %%
import numpy as np
import matplotlib.pyplot as mpl

# %matplotlib inline
mpl.matplotlib.rcParams['figure.figsize'] = (10, 6)

# %%
#from numpy import *
#from matplotlib.pyplot import *

mpl.rc('xtick', labelsize=7)
mpl.rc('ytick', labelsize=7)

mpl.rc('lines', linewidth=4)
                   
N = 20
x = np.linspace(-N, N, 2*N, endpoint=False)
f, ax = mpl.subplots(1,2)
ax[0].set_title('a symmetric function')
ax[0].plot(x,abs(x))

#ax[1].set_prop_cycle(cycler('color', ['c', 'm', 'y', 'k']) + cycler('lw', [1, 2, 3, 4]))
ax[1].set_title('an anti-symmetric function')
ax[1].plot(x,x)

                     
mpl.show()
f.savefig("test.png", format='png', dpi=600)

# %% [markdown]
# ## spin-orbital
#
# Electrons are fermions and fermions are described by anti-symmetric wavefunctions. But our spatial orbital $\phi_1(\vec{r}_1)\phi_2(\vec{r}_2)$ is symmetric, this means that the spin wavefunction must be anti-symmetric.
#
# For instance:
#
# $$\alpha(1)\alpha(2)=\alpha(2)\alpha(1)$$
# $$\beta(1)\beta(2)=\beta(2)\beta(1)$$
#
# are symmetric functions

# %% [markdown]
# and
#
# $$\alpha(1)\beta(2)$$
# $$\beta(1)\alpha(2)$$
#
# are neither symmetric nor anti-symmetric. But we can combine them to obtain
#
# $$\frac{1}{\sqrt{2}}(\alpha(1)\beta(2) + \beta(1)\alpha(2))$$
# $$\frac{1}{\sqrt{2}}(\alpha(1)\beta(2) - \beta(1)\alpha(2))$$
#
# the first one is symmetric, while the second one is anti-symmetric. So the spin-orbital is:
#
# $$\sigma(\vec{r}_1,\vec{r}_2,s_1,s_2)=\phi_1(\vec{r}_1)\phi_2(\vec{r}_2)\frac{1}{\sqrt{2}}[(\alpha(1)\beta(2) - \beta(1)\alpha(2)]$$

# %% [markdown]
# ## Many electrons atom
#
# We have shown how to find symmetric and anti-symmetric spin functions for 2 electrons, what about 3 electrons?
#
# $$1s(1)1s(2)1s(3)\alpha(1)\alpha(2)\alpha(3)$$
#
# It is not possible to find an anti-symmetric function for $1s^3$ configuration!
#
#
# <br><br>
# <center style="font-size:40px;color:red"> it is not possible!</center>

# %% [markdown]
# Let's try with $1s^22s^1$
#
# $$1s1s2s\alpha\beta\alpha$$
#
# swapping 1 and 2 gives
#
# $$1s1s2s\beta\alpha\alpha$$
#
# we can write a function that is anti-symmetric for $1\to 2$ by taking the difference
#
# $$1s1s2s(\alpha\beta\alpha-\beta\alpha\alpha)$$

# %% [markdown]
# applying the same idea we can write
#
# $$1s1s2s(\alpha\beta\alpha-\beta\alpha\alpha)-2s1s1s(\alpha\beta\alpha-\alpha\alpha\beta)$$
#
# that is anti-symmetric for $1\to 2$ and $1\to 3$
#
# and by taking the second term and making it anti-symetric for $1\to 2$ and $2\to 3$
#
# $$\frac{1}{\sqrt{6}}[1s1s2s(\alpha\beta\alpha-\beta\alpha\alpha)+1s2s1s(\beta\alpha\alpha-\alpha\alpha\beta)+2s1s1s(\alpha\alpha\beta-\alpha\beta\alpha)]$$

# %% [markdown]
# ## slater determinants
#
# Each electron can in fact be in state
#
# $$1s\alpha$$
# $$1s\beta$$
# $$2s\alpha$$
#
# So we can write this as a determinant
#
# $$\frac{1}{\sqrt{6}}\left|\begin{array}{ccc}1s(1)\alpha(1)&1s(2)\alpha(2)&1s(3)\alpha(3)\\
# 1s(1)\beta(1)&1s(2)\beta(2)&1s(3)\beta(3)\\
# 2s(1)\alpha(1)&2s(2)\alpha(2)&2s(3)\alpha(3)\end{array}\right|$$

# %% [markdown]
# Remember
#
# $$\left|\begin{array}{ccc}a&b&c\\
# d&e&f\\
# g&f&g\end{array}\right| = a\left|\begin{array}{cc}e&f\\
# h&i\end{array}\right| -b\left|\begin{array}{cc}d&f\\
# g&i\end{array}\right| + c\left|\begin{array}{cc}d&e\\
# g&h\end{array}\right|$$
#
# we can use the following notation to simplify the determinant:
#
# $$\frac{1}{\sqrt{6}}\left|\begin{array}{ccc}1s(1)&1s(2)&1s(3)\\
# 1\bar{s}(1)&1\bar{s}(2)&1\bar{s}(3)\\
# 2s(1)&2s(2)&2s(3)\end{array}\right|$$
#
# Let's check this with the excited states of Helium

# %% [markdown]
# ## excited states of helium
#
# Let's look at the first exicted state of Helium. The electronic configuration is $1s2s$. This spacial wave function is not symmetric nor anti-symmetric.
#
# We can build symmetric and anti-symmetric spatial wavefunctions as:
#
# $$\frac{1}{\sqrt{2}}(1s(1)2s(2) + 2s(1)1s(2))$$
# $$\frac{1}{\sqrt{2}}(1s(1)2s(2) - 2s(1)1s(2))$$

# %% [markdown]
# we also remember that the spin wavefunction are:
#
# $$\alpha(1)\alpha(2)$$
# $$\beta(1)\beta(2)$$
# $$\frac{1}{\sqrt{2}}(\alpha(1)\beta(2) + \beta(1)\alpha(2))$$
# $$\frac{1}{\sqrt{2}}(\alpha(1)\beta(2) - \beta(1)\alpha(2))$$

# %% [markdown]
# so to get a spin-orbit $\sigma_A$ that is anti-symmetric we can combine
#
# $$\sigma_A = \frac{1}{\sqrt{2}}[1s(1)2s(2) + 2s(1)1s(2)]\frac{1}{\sqrt{2}}[\alpha(1)\beta(2) - \beta(1)\alpha(2)]$$
#
# $$
# \sigma_A = \frac{1}{\sqrt{2}}[1s(1)2s(2) - 2s(1)1s(2)] \left\{ \begin{array}\alpha(1)\alpha(2)\\
# \frac{1}{\sqrt{2}}(\alpha(1)\beta(2) + \beta(1)\alpha(2))\\
# \beta(1)\beta(2)\end{array}\right.
# $$

# %% [markdown]
# Remember that there are 4 states for the $1s2s$ configuration:
#
# $$(2l_1+1)(2l_2+1)(2s_1+1)(2s_2+1)=1\times1\times2\times2=4$$
#
# But using the Slater determinant
# $$
# a\left|\begin{array}{cc}1s(1)\alpha(1)&1s(2)\alpha(2)\\
# 2s(1)\alpha(1)&2s(2)\alpha(2)\end{array}\right|
# $$
#
# which gives $\frac{1}{\sqrt{2}}[1s(1)2s(2) - 2s(1)1s(2)]\alpha(1)\alpha(2)$
#
# <center style="color:red">So the Slater determinants do provide a way to find anti-symmetric spin-orbitals but doesn't provide all the solutions</center>

# %% [markdown]
# We can use the variational method and find the expectation value for the energy using the four states to find out which is the basal wavefunction.
#
# $$
# \langle E \rangle= \frac {\iint\limits\psi^*(\vec{r}_1,\vec{r}_2)\hat{\mathcal{H}}\,\psi(\vec{r}_1,\vec{r}_2)d\tau_1\,d\tau_2}{ \iint\limits\psi^*(\vec{r}_1,\vec{r}_2)\psi(\vec{r}_1,\vec{r}_2)d\tau_1\,d\tau_2}
# $$
#
# where the **Hamiltonian** is
#
# $$
# \hat{\mathcal{H}}=-\frac{1}{2}\nabla_1^2-\frac{1}{2}\nabla_2^2-\frac{2}{\vec{r}_1}-\frac{2}{\vec{r}_2}+\frac{1}{r_{12}}
# $$

# %% [markdown]
# and can be simplified as
#
# $$
# \hat{h}(\vec{r}_i)=-\frac{1}{2}\nabla_i^2-\frac{2}{\vec{r}_i}
# $$
#
# $$
# \langle E \rangle =\frac{1}{2}\iint\limits [1s_1^*(\vec{r}_1)2s_2^*(\vec{r}_2) \pm 2s_1^*(\vec{r}_1)1s_2^*(\vec{r}_2)] \hat{\mathcal{H}}[1s_1^*(\vec{r}_1)2s_2(\vec{r}_2) \pm 2s_1(\vec{r}_1)1s_2(\vec{r}_2)]d\tau_1\,d\tau_2
# $$
#
# because the wave functions are normalized and we can ignore the denominator.
#
# $$
# \langle E \rangle =\frac{1}{2}\iint\limits [1s_1^*(\vec{r}_1)2s_2^*(\vec{r}_2) \pm 2s_1^*(\vec{r}_1)1s_2^*(\vec{r}_2)] \Bigl[\hat{h}(\vec{r}_1)+\hat{h}(\vec{r}_2)+r_{12}^{-1}\Bigr] [1s_1^*(\vec{r}_1)2s_2(\vec{r}_2) \pm 2s_1(\vec{r}_1)1s_2(\vec{r}_2)]d\tau_1\,d\tau_2
# $$

# %% [markdown]
# For the first two terms of the **Hamiltonian** the expansion is:
#
# $$
#  =\frac{1}{2}\left\{ \int\limits 1s_1^*(\vec{r}_1) \hat{h}(\vec{r}_1) 1s_1(\vec{r}_1)d\tau_1 \int\limits 2s_2^*(\vec{r}_2)  2s_2(\vec{r}_2)d\tau_2 \\
# +\int\limits 2s_2^*(\vec{r}_2) \hat{h}(\vec{r}_2) 2s_2(\vec{r}_2)d\tau_2 \int\limits 1s_1^*(\vec{r}_1)  1s_1(\vec{r}_1)d\tau_1 \\
# +\int\limits 1s_2^*(\vec{r}_2) \hat{h}(\vec{r}_2) 1s_2(\vec{r}_2)d\tau_2 \int\limits 2s_1^*(\vec{r}_1)  2s_1(\vec{r}_1)d\tau_1  \\
# +\int\limits 2s_1^*(\vec{r}_1) \hat{h}(\vec{r}_1) 2s_1(\vec{r}_1)d\tau_1 \int\limits 1s_2^*(\vec{r}_2)  1s_2(\vec{r}_2)d\tau_2  \\ \right.
# $$

# %% [markdown]
# $$
# \left. \pm \int\limits 1s_1^*(\vec{r}_1) \hat{h}(\vec{r}_1) 2s_1(\vec{r}_1)d\tau_1 \int\limits 2s_2^*(\vec{r}_2)  1s_2(\vec{r}_2)d\tau_2  \\
# \pm\int\limits 2s_2^*(\vec{r}_2) \hat{h}(\vec{r}_2) 1s_2(\vec{r}_2)d\tau_2 \int\limits 1s_1^*(\vec{r}_1)  2s_1(\vec{r}_1)d\tau_1  \\
# \pm \int\limits 2s_1^*(\vec{r}_1) \hat{h}(\vec{r}_2) 1s_1(\vec{r}_1)d\tau_1 \int\limits 1s_2^*(\vec{r}_2)  2s_2(\vec{r}_2)d\tau_2  \\
# \pm \int\limits 1s_2^*(\vec{r}_2) \hat{h}(\vec{r}_2) 2s_2(\vec{r}_2)d\tau_2 \int\limits 2s_1^*(\vec{r}_1)  1s_1(\vec{r}_1)d\tau_1\right\}
# $$
#
# Only the first 4 terms survives, since functions $1s$ and $2s$ are orthogonal.

# %% [markdown]
# because swapping label 1 and 2 leaves the integral identical, we can write the average value:
#
# $$
# = \int\limits 1s_1^*(\vec{r}_1) \hat{h}(\vec{r}_1) 1s_1(\vec{r}_1)d\tau_1
# +\int\limits 2s_1^*(\vec{r}_1) \hat{h}(\vec{r}_1) 2s_1(\vec{r}_1)d\tau_1
# $$

# %% [markdown]
# We are left with the two-electron integrals:
#
# $$
#  =\frac{1}{2}\iint\limits [1s_1^*(\vec{r}_1)2s_2^*(\vec{r}_2) \pm 2s_1^*(\vec{r}_1)1s_2^*(\vec{r}_2)] r_{12}^{-1} [1s_1^*(\vec{r}_1)2s_2(\vec{r}_2) \pm 2s_1(\vec{r}_1)1s_2(\vec{r}_2)]d\tau_1\,d\tau_2
# $$
#
# which gives:
#
# $$
#  =\iint\limits 1s_1^*(\vec{r}_1)2s_2^*(\vec{r}_2) r_{12}^{-1} 1s_1(\vec{r}_1)2s_2(\vec{r}_2) d\tau_1\,d\tau_2 \\
# \pm \iint\limits 1s_1^*(\vec{r}_1)2s_2^*(\vec{r}_2) r_{12}^{-1} 2s_1(\vec{r}_1)1s_2(\vec{r}_2) d\tau_1\,d\tau_2
# $$
#
# $$\langle E \rangle = \epsilon_1 + \epsilon_2 + J \pm K$$

# %% [markdown]
# So for the symmetric (spatial) function
#
# $$\phi_S = \frac{1}{\sqrt{2}}[1s(1)2s(2) + 2s(1)1s(2)]$$
#
# we have
#
# $$\langle E \rangle = \epsilon_1 + \epsilon_2 + J + K$$
#
# while we have
#
# $$\langle E \rangle = \epsilon_1 + \epsilon_2 + J - K$$

# %% [markdown]
# for the anti-symmetric spatial function
#
# $$
# \phi_A = \frac{1}{\sqrt{2}}[1s(1)2s(2) - 2s(1)1s(2)]
# $$
#
# Because both J and K are positive in that example the triplet of state lies below the singlet of state. J is always positive while K is positive when $r_1$ and $r_2$ are smaller that then node of $2s$ and negative otherwise. But since the repulsion term make the integral small when $r_1$ and $r_2$ are much different, the integral is positive alltogether. We refer to J and K as Coulomb integrals and Exchange integrals.

# %% [markdown]
# ## the radial functions
# $$
# R_{n,l}(r)=\sqrt{\left(\frac{2Z}{na_0}\right)^{3}\frac{(n-l-1)!}{2n\left[(n+l)^{3}\right]}}\,e^{-\rho/2}L_{n+l}^{2l+1}(\rho),
# $$
# where $\rho$ and the Laguerre polynomia L are
# $$
# \rho=\frac{2z}{na_0}r\qquad\text{y }\qquad L_{n+l}^{2l+1}(\rho)=\sum_{k=0}^{n-l-1}(-1)^{k+1}\frac{\left[(n+1)!\right]^2}{(n-l-1-k)!(2l+1+k)!k!}\rho^{k}.
# $$

# %% [markdown]
# $$
# \begin{split}
# n&=1:\qquad \quad l=0, \qquad R_{1,0}(r)=\Bigl(\frac{Z}{a_0}\Bigr)^{3/2}2e^{\frac{-Zr}{a_0}}\\[2mm]
# n&=2:\qquad \left\{ \begin{aligned}
# l=0, \qquad R_{2,0}(r)&=\frac{(Z/a_0)^{3/2}}{2\sqrt{2}}\Bigl(2-\frac{Zr}{a_0}\Bigr)e^{\frac{-Zr}{2a_0}}\\
# l=1, \qquad R_{2,1}(r)&=\frac{(Z/a_0)^{3/2}}{2\sqrt{6}}\frac{Zr}{a_0}e^{\frac{-Zr}{2a_0}}
# \end{aligned}\right.\\[2mm]
# n&=3:\qquad \left\{ \begin{aligned}
# l=0, \qquad R_{3,0}(r)&=\frac{(Z/a_0)^{3/2}}{9\sqrt{3}}\Bigl(6-\frac{4Zr}{a_0}+\Bigl(\frac{2Zr}{3a_0}\Bigr)^2\Bigr)e^{\frac{-Zr}{3a_0}}\\
# l=1, \qquad R_{3,1}(r)&=\frac{(Z/a_0)^{3/2}}{9\sqrt{6}}\Bigl(4-\frac{2Zr}{a_0}\Bigr)\frac{2Zr}{a_0}e^{\frac{-Zr}{3a_0}}\\
# l=2, \qquad R_{3,2}(r)&=\frac{(Z/a_0)^{3/2}}{9\sqrt{30}}\Bigl(\frac{2Zr}{3a_0}\Bigr)^2e^{\frac{-Zr}{3a_0}}
# \end{aligned}\right.
# \end{split}
# $$

# %% [markdown]
# ## the orbitals
#
# \begin{equation*}
# \Psi_{100}=1s=\frac{Z^{3/2}}{\pi^{1/2}}e^{-Zr}=N_1e^{-Zr}
# \end{equation*}
# \begin{equation*}
# \Psi_{200}=2s=\frac{Z^{3/2}}{4(2\pi^{1/2})}\bigl(2-Zr\bigr)e^{-Zr/2}=N_2\bigl(2-Zr\bigr)e^{-Zr/2}
# \end{equation*}
# \begin{equation*}
# \Psi_{21\cos\phi}=2p_x=\frac{Z^{5/2}}{4(2\pi^{1/2})}re^{-Zr/2}\sin \theta \cos \phi =N_2 re^{-Zr/2}\sin \theta \cos \phi
# \end{equation*}
# \begin{equation*}
# \Psi_{21\sin\phi}=2p_y=\frac{Z^{5/2}}{4(2\pi^{1/2})}re^{-Zr/2}\sin \theta \sin \phi =N_2 re^{-Zr/2}\sin\theta \sin\phi
# \end{equation*}
# \begin{equation*}
# \Psi_{210}=2p_z=\frac{Z^{5/2}}{4(2\pi^{1/2})}re^{-Zr/2} \cos \theta =N_2 re^{-Zr/2}\cos\theta
# \end{equation*}
# \begin{align*}
# \Psi_{300}=3s=\frac{Z^{3/2}}{81(3\pi^{1/2})}&\bigl(27-18Zr+2Z^2r^2\bigr)e^{-Zr/3}=\\
# &N_3\bigl(27-18Zr+2Z^2r^2\bigr) e^{-Zr/3}
# \end{align*}
# \begin{align*}
# \Psi_{31\cos\phi}=3p_x=2^{1/2}\frac{Z^{5/2}}{81(\pi^{1/2})}&\bigl(6-Zr\bigr)re^{-Zr/3}\sin\theta \cos\phi =\\
# &N_3 \bigl(6-Zr\bigr)re^{-Zr/3}\sin\theta \cos\phi
# \end{align*}
# \begin{align*}
# \Psi_{31\sin\phi}=3p_y=2^{1/2}\frac{Z^{5/2}}{81(\pi^{1/2})}&\bigl(6-Zr\bigr)re^{-Zr/3}\sin\theta \sin\phi =\\
# &N_3 \bigl(6-Zr\bigr)re^{-Zr/3}\sin\theta \sin\phi
# \end{align*}
# \begin{align*}
# \Psi_{31\cos\phi}=3p_z=2^{1/2}\frac{Z^{5/2}}{81(\pi^{1/2})}&\bigl(6-Zr\bigr)re^{-Zr/3}\cos\theta =\\
# &N_3 \bigl(6-Zr\bigr)re^{-Zr/3}\cos\theta
# \end{align*}
# \begin{align*}
# \Psi_{320}=3d_z^2=2^{1/2}\frac{Z^{7/2}}{81(6\pi^{1/2})}&r^2e^{-Zr/3}\bigl(3\cos^2\theta-1\bigr) =\\
# &N_4 r^2e^{-Zr/3}\bigl(3\cos^2\theta-1\bigr)
# \end{align*}
# \begin{align*}
# \Psi_{32\cos\phi}=3d_{xz}=2^{1/2}\frac{Z^{7/2}}{81(6\pi^{1/2})}&r^2e^{-Zr/3}\sin\theta \cos\theta \cos\phi =\\
# &N_5 r^2e^{-Zr/3}\sin\theta \cos\theta \cos\phi
# \end{align*}
# \begin{align*}
# \Psi_{32\sin\phi}=3d_{yz}=2^{1/2}\frac{Z^{7/2}}{81(6\pi^{1/2})}&r^2e^{-Zr/3}\sin\theta \cos\theta \sin\phi =\\
# &N_5 r^2e^{-Zr/3}\sin\theta \cos\theta \sin\phi
# \end{align*}
# \begin{align*}
# \Psi_{32\cos2\phi}=3d_{x^2-y^2}=2^{1/2}\frac{Z^{7/2}}{81(6\pi^{1/2})}&r^2e^{-Zr/3}\sin^2\theta \cos2\phi =\\
# &N_6 r^2e^{-Zr/3}\sin^2\theta \cos2\phi
# \end{align*}
# \begin{align*}
# \Psi_{32\sin2\phi}=3d_{xy}=2^{1/2}\frac{Z^{7/2}}{81(6\pi^{1/2})}&r^2e^{-Zr/3}\sin^2\theta \sin2\phi =\\
# &N_6 r^2e^{-Zr/3}\sin^2\theta \sin2\phi
# \end{align*}

# %%
mpl.rc('xtick', labelsize=7)
mpl.rc('ytick', labelsize=7)
mpl.rc('lines', linewidth=1)

r = np.linspace(0.00000001, 10, 500, endpoint=False)

Z = 2
_1s = np.exp(-Z*abs(r))
_2s = (2 - Z*r) * np.exp(-Z*abs(r/2))

f, ax = mpl.subplots(3,3)

ax[1,0].grid(True)
ax[1,0].set_xlim([0,6])
ax[1,0].set_ylim([-.1,.3])

ax[1,0].set_title('1s1s')
ax[1,0].plot(r,_1s)
ax[1,0].plot(r,_1s*_1s)

ax[1,1].grid(True)
ax[1,1].set_xlim([0,6])
ax[1,1].set_ylim([-.1,3])

ax[1,1].set_title('1/r')
ax[1,1].plot(r,1/r)

ax[1,2].grid(True)
ax[1,2].set_xlim([0,2])
ax[1,2].set_ylim([-.1,3])

ax[1,2].set_title('1s1s * 1/r * 1s1s')
ax[1,2].plot(r,_1s*_1s * 1/r * _1s*_1s)

ax[0,0].grid(True)
ax[0,0].set_xlim([0,6])
ax[0,0].set_ylim([-.1,.3])

ax[0,0].set_title('1s2s')
ax[0,0].plot(r,_1s)
ax[0,0].plot(r,_2s)
ax[0,0].plot(r,_1s*_2s)

ax[0,1].grid(True)
ax[0,1].set_xlim([0,6])
ax[0,1].set_ylim([-.1,3])

ax[0,1].set_title('1/r')
ax[0,1].plot(r,1/r)

ax[0,2].grid(True)
ax[0,2].set_xlim([0,2])
ax[0,2].set_ylim([-.1,3])

ax[0,2].set_title('1s2s * 1/r * 1s2s')
ax[0,2].plot(r,_1s*_2s * 1/r * _1s*_2s)

ax[2,0].grid(True)
ax[2,0].set_xlim([0,6])
ax[2,0].set_ylim([-.1,.3])

ax[2,0].set_title('2s2s')
ax[2,0].plot(r,_2s)
ax[2,0].plot(r,_2s*_2s)

ax[2,1].grid(True)
ax[2,1].set_xlim([0,6])
ax[2,1].set_ylim([-.1,3])

ax[2,1].set_title('1/r')
ax[2,1].plot(r,1/r)

ax[2,2].grid(True)
ax[2,2].set_xlim([0,2])
ax[2,2].set_ylim([-.1,3])

ax[2,2].set_title('2s2s * 1/r * 2s2s')
ax[2,2].plot(r,_2s*_2s * 1/abs(r) * _2s*_2s)

                     
mpl.show()
f.savefig("orbitals.png", format='png', dpi=600)

# %% [markdown]
# <center><img src="./orbitals.png"></img></center>

# %% [markdown]
# for SCF in python look here:
# http://joshuagoings.com/2013/04/24/hartree-fock-self-consistent-field-procedure/

# %%
from mpl_toolkits.mplot3d import axes3d
#from matplotlib.pyplot import *

fig = mpl.figure()
ax = fig.add_subplot(111, projection='3d')

N = 2
X = np.linspace(-N, N, 300, endpoint=False) 
Y = np.linspace(-N, N, 300, endpoint=False) 

r1, r2 = np.meshgrid(X , Y )

Z = 2

_1s1 = np.exp(-Z*abs(r1))
_2s2 = (2 - Z*r2) * np.exp(-Z*abs(r2/2))
_1s2 = np.exp(-Z*abs(r2))
_2s1 = (2 - Z*r1) * np.exp(-Z*abs(r1/2))

I = _1s1*_2s2*(1/abs(100))*_2s1*_1s2

ax.plot_wireframe(r1, r2, I, rstride=10, cstride=10)
#ax.view_init(0,0)
mpl.show()

# %%
import sympy as sp
#import numpy as np
Z = 2
sp.var('r1 r2')

_1s1 = Z*sp.exp(-Z*abs(r1))
_2s2 = (2 - Z*r2) * sp.exp(-Z*abs(r2/2))
_1s2 = Z*sp.exp(-Z*abs(r2))
_2s1 = (2 - Z*r1) * sp.exp(-Z*abs(r1/2))

print( sp.Integral(_1s1**2, (r1,0,sp.oo)).evalf().round(2) ) 
print( sp.Integral(_2s2**2, (r2,0,sp.oo)).evalf() )
print( sp.Integral(_1s2**2, (r2,0,sp.oo)).evalf() )
print( sp.Integral(_2s1**2, (r1,0,sp.oo)).evalf() )
# Out:
# 1.00
# 1.00000000000000
# 1.00000000000000
# 1.00000000000000

# %% [markdown]
# ## effective charge
#
# \begin{equation}
# \psi(\vec{r}_1,\vec{r}_2)=1s(\vec{r}_1)1s(\vec{r}_2)=\tfrac{Z^2}{\pi}e^{-Z(r_1+r_2)}
# \end{equation}
#
# \begin{equation}
# \begin{split}
# \psi^{modificada}=\psi'(\vec{r}_1,\vec{r}_2;\gamma)=&\frac{(\gamma Z)^2}{\pi}e^{-\gamma Z(r_1+r_2)}=\\
# =&K'e^{-Z^*(r_1+r_2)}=1s'(\vec{r_1})1s'(\vec{r_2}),
# \end{split}
# \end{equation}
#
# \begin{equation}
# E(Z^{*})=\frac{\bigl<\psi^{mod}|\mathcal{H}|\psi^{mod}\bigr>}{\bigl<\psi^{mod}|\psi^{mod}\bigr>}=Z^{*2}-2ZZ^{*}+\frac{5}{8}Z^{*}
# \end{equation}

# %%
import sympy as sp
#import numpy as np
Z = 2
z = sp.Symbol('z')
y = z**2 - 2*Z*z + (5/8)*z
yprime = y.diff(z)
print('derivative: ' + str(yprime))
sol = sp.solve(yprime)
print('solution (Z*): ' + str(sol[0].round(4)))
print('shielding constant Z-Z*: ')
print(sp.nsimplify(Z-sol[0]))
# Out:
# derivative: 2*z - 3.375
# solution (Z*): 1.6875
# shielding constant Z-Z*:
# 5/16

# %% [markdown]
# \begin{equation}
# \frac{dE}{dZ^*}=2Z^*-2Z+\frac{5}{8}=0.
# \end{equation}
#
#
# The optimal value is $Z^*=Z-\frac{5}{16}$ and by replacing $Z^*$ we obtain an energy of -2,8477 hartrees, less that the -2,75 hartrees that we got initially, and closer to the exeprimental -2.9037.
#
# \begin{equation}
# \begin{split}
# \psi^{mejorada}=\psi'(\vec{r}_1,\vec{r}_2;\gamma)=&\tfrac{(\gamma Z)^2}{\pi}e^{-\gamma Z(r_1+r_2)}=\\
# =&K'e^{-\frac{27}{32}Z(r_1+r_2)}=K'e^{-\frac{27}{16}(r_1+r_2)}
# \end{split}
# \end{equation}
#
# and $\sigma=Z-Z^*$ is referred to as the shielding constant.

# %%
# we can no evaluate the energy at the optimal value of Z*
print('our best approximation for energy is ' + str( y.evalf(subs={z:sol[0]}).round(3)) )
# Out:
# our best approximation for energy is -2.848

# %%
from matplotlib.pyplot import *
# remote z variable
del z

rc('xtick', labelsize=12)
rc('ytick', labelsize=12)
rc('lines', linewidth=1)

z = linspace(0, 3, 50, endpoint=False)

Z = 2
E = z**2 - 2*Z*z + (5/8)*z

# plot the function
f , a = subplots(1)
a.grid(True)
plot(z,E)

# plot an additional point at the best value
z = 2-(5/16)
E = z**2 - 2*Z*z + (5/8)*z

plot(2-(5/16), E, 'bs')
axis([0, 2.5, -4, 0])

# setup the axes and titles
xlabel('$Z^*$', fontsize=14, color='red')
ylabel('$E(Z^{*})$', fontsize=14, color='red')
title('energy minimization', fontsize=14, color='red')

show()

# %% [markdown]
# # photoelectronic spectroscopy

# %% [markdown]
# ## photoelectronic spectroscopy
#
#  - X-ray Photoelectron Spectroscopy (XPS
#  - Electron Spectroscopy for Chemical Analysis (ESCA)
#  - Ultraviolet Photoelectron Spectroscopy (UPS)
#  - Photoemission Spectroscopy (PES)
#
#  <a href="http://mmrc.caltech.edu/SS_XPS/XPS_PPT/XPS_Slides.pdf"><img src="../img/PESSpectrometer.png" width="500"></a>
#
# #### PES is an application of the photoelectric effect

# %% [markdown]
# ## PES spectrometer
#
# <a href="http://mmrc.caltech.edu/SS_XPS/XPS_PPT/XPS_Slides.pdf"><img src="../img/PESSchema.png" width="400"></a>

# %% [markdown]
# ## Koopman's theorem
#
# The koopman's theorem states that the **binding energy (BE)** is equal to
#
# $$
# BE = E_{final}(n-1) - E_{initial}(n)
# $$
#
# So BE can be computed within the Hartree Fock theory assuming that
#  - no orbital relaxation occurs
#  - electronic correlation effects are weak
#
# In other word that K's theorem says is that the wavefunctions of the neutral atom are valid to describe the ion.
#
# <img src="../img/koopman.png" width="300">

# %% [markdown]
# ## the energy of the orbitals
#
# <img src="../img/PES_EO.png" width="600">

# %% [markdown]
# ## PES applications
#
# <a href="http://mmrc.caltech.edu/SS_XPS/XPS_PPT/XPS_Slides.pdf"><img src="../img/PES_oxide.png" width="500"></a>

# %% [markdown]
# ## PES applications
#
# <a href="http://mmrc.caltech.edu/SS_XPS/XPS_PPT/XPS_Slides.pdf"><img src="../img/PES_surfaceComposition.png" width="400"></a>

# %% [markdown]
# ## PES applications
#
# ### chemical shifts
#
# <a href="http://mmrc.caltech.edu/SS_XPS/XPS_PPT/XPS_Slides.pdf"><img src="../img/PES_CS1.png" width="400"></a><a href="http://mmrc.caltech.edu/SS_XPS/XPS_PPT/XPS_Slides.pdf"><img src="../img/PES_CS2.png" width="400"></a>
